# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t,theta,omega=np.loadtxt('dat.csv', unpack=True,delimiter =',')

# %%
t2,theta2,omega2 = np.loadtxt('dat2.csv', unpack=True,delimiter =',')

# %%
plt.plot(t,theta)
plt.plot(t2,theta2)
